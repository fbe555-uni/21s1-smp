# %%
from sympy import FiniteSet
import matplotlib.pyplot as plt
from matplotlib_venn import *
S = set(['Rain_on_day_1', 'No_rain_on_day_1', 'Rain_on_day_2', 'No_rain_on_day_2'])
A = set(['Rain_on_day_1'])
B = set(['Rain_on_day_2'])
venn2(subsets=(3, 3, 1), set_labels=('A', 'B'))
