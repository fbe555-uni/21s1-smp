# %%
load('../../F21-ETALA/etala_utilities.sage')
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# ##### F21ETSMP Group Assignment 13
# # Ohm’s Law - Linear Modelling

# %% [markdown]
# You are given the assignment to verify Ohm’s law in the lab. In one form, Ohm’s Law states that voltage divided by resistance is equal to current:
# $$\frac U R=I$$
# You have a $R=100\Omega$ Resistor, and measure the current going through the resistor at different voltages:
# {{ LList([-10,-5, 0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75], name='U', wrapper='$$') }}
# {{ LList([-0.118,-0.048, 0.011, 0.056, 0.088, 0.160, 0.215, 0.284, 0.296, 0.307, 0.383, 0.477, 0.479, 0.01, 0.03, 0.05,-0.01, 0.0], name='I', wrapper='$$') }}
# Based on the measured data answer the following questions:

# %% [markdown]
# ## 1.  Plot the data for voltage and current.

# %%
plt.plot(U, I, 'o')
plt.xlabel('U [V]')
plt.ylabel('I [A]')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %% [markdown]
# ## 2.  Formulate a hypothesis test based on Ohm’s law for the slope.

# %% [markdown]
# To test if there is the expected correlation between current and voltage for a resistor, Ohm's law is used to form the null hypothesis, using the statistical model:
# $y_i = \alpha + \beta x_i + \epsilon_i $
# This yields the following hypotheses:
# $ H_0 \text{: } \beta = \frac 1 R $
# $ H_1 \text{: } \beta \ne \frac 1 R $

# %% [markdown]
# ## 3.  Determine a linear model for the data (slope and interception with the y-axis).

# %%
4.  Plot the linear model together with the data.
# Out:
#   File "<ipython-input-9-50123265bff7>", line 1
#     RealNumber('4.')  Plot the linear model together with the data.
#                       ^
# SyntaxError: invalid syntax

# %%
5.  Can you reject the NULL hypothesis

# %%
6.  Calculate the residuals and make the residual plot.
# Out:
#   File "<ipython-input-11-93bd018288ac>", line 1
#     RealNumber('6.')  Calculate the residuals and make the residual plot.
#                       ^
# SyntaxError: invalid syntax

# %%
7.  Based on the residual plot, is the linear model at good fit?
# Out:
# Object `fit` not found.

# %%
7.  Based on the residual plot, is the linear model at good fit

# %%
8.  Find the 95% confidence interval for the estimate of the slope.
# Out:
#   File "<ipython-input-13-728e407cdd9e>", line 1
#     RealNumber('8.')  Find the Integer(95)% confidence interval for the estimate of the slope.
#                       ^
# SyntaxError: invalid syntax

# %%
9.  Plot the 95% confidence interval together with the data.
# Out:
#   File "<ipython-input-14-b818349ef955>", line 1
#     RealNumber('9.')  Plot the Integer(95)% confidence interval together with the data.
#                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# 10.  Are there any outliers in the experiment? Why is that?

# %% [markdown]
# 11.Based on the residual plot would you conclude that Ohm’s Law is true (that there is a linearconnection between Voltage and Current)?

# %%
12.  Redesign your experiment to avoid outliers.
# Out:
#   File "<ipython-input-15-7a5e59f2f0fa>", line 1
#     RealNumber('12.')  Redesign your experiment to avoid outliers.
#                        ^
# SyntaxError: invalid syntax

# %%
13.Make a Matlab program that generates data for your new experiment. Assume that current is measured with a measurement noise that is Gaussian distributed with a mean of 0 andstandard deviation of 0.02A.
# Out:
#   File "<ipython-input-16-8230bc755814>", line 1
#     Integer(13).Make a Matlab program that generates data for your new experiment. Assume that currentis measured with a measurement noise that is Gaussian distributed with a mean of Integer(0) andstandard deviation of RealNumber('0.')02A.
#                      ^
# SyntaxError: invalid syntax

# %%
14.  With the new data, repeat question 1-9.
# Out:
#   File "<ipython-input-17-1a9e9fad3d17>", line 1
#     RealNumber('14.')  With the new data, repeat question Integer(1)-RealNumber('9.')
#                        ^
# SyntaxError: invalid syntax
